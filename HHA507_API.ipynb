# %% [markdown]
# <a href="https://colab.research.google.com/github/victory1217/HHA507_introAPI/blob/main/HHA507_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**HHA 507- API Introduction Assignment**
# ##Victoria Rodriguez Silva
#
# ###COVID-19 Tracker Canada Webpage: https://covid19tracker.ca/
# ###API Documentation Reference: https://api.covid19tracker.ca/docs/1.0/overview

# %% [markdown]
# ## **Imported the request and pandas packages**

# %%
import requests 
import pandas as pd

# %% [markdown]
# ## **GET Request for a basic summary of COVID19 Tracking in Canada**

# %%
jsonresponse = requests.get('https://api.covid19tracker.ca/summary')
jsonresponse.status_code
# Out:
# 200

# %% [markdown]
# ##**View of basic summary information for COVID19 Tracking in Canada**

# %%
jsonresponse.json()
# Out:
# {'data': [{'change_cases': '1924',
#    'change_criticals': '-1',
#    'change_fatalities': '9',
#    'change_hospitalizations': '-126',
#    'change_recoveries': '1075',
#    'change_tests': '35116',
#    'change_vaccinated': '25973',
#    'change_vaccinations': '41538',
#    'change_vaccines_distributed': '0',
#    'latest_date': '2021-09-26',
#    'total_cases': '1602650',
#    'total_criticals': '753',
#    'total_fatalities': '27643',
#    'total_hospitalizations': '2273',
#    'total_recoveries': '1528511',
#    'total_tests': '42130219',
#    'total_vaccinated': '26756826',
#    'total_vaccinations': '55810920',
#    'total_vaccines_distributed': '63906444'}],
#  'last_updated': '2021-09-26 16:08:06'}

# %% [markdown]
# ##**GET Request for latest confirmed cases within COVID19 Tracking System for Canada**

# %%
jsonresponse2 = requests.get('https://api.covid19tracker.ca/cases')
jsonresponse2.status_code
# Out:
# 200

# %% [markdown]
# ##**View of latest confirmed cases in COVID19 Tracking System for Canada**

# %%
jsonresponse2.json()
# Out:
# {'current_page': 1,
#  'data': [{'age': 'Pending',
#    'city': 'Pending',
#    'confirmed_presumptive': 'CONFIRMED',
#    'date': '2021-02-03 16:22:29',
#    'hr_uid': None,
#    'id': 799345,
#    'province': 'BC',
#    'source': 'https://news.gov.bc.ca/releases/2021HLTH0028-000199',
#    'travel_history': 'Pending'},
#   {'age': 'Pending',
#    'city': 'Pending',
#    'confirmed_presumptive': 'CONFIRMED',
#    'date': '2021-02-03 16:22:29',
#    'hr_uid': None,
#    'id': 799344,
#    'province': 'BC',
#    'source': 'https://news.gov.bc.ca/releases/2021HLTH0028-000199',
#    'travel_history': 'Pending'},
#   {'age': 'Pending',
#    'city': 'Pending',
#    'confirmed_presumptive': 'CONFIRMED',
#    'date': '2021-02-03 16:22:29',
#    'hr_uid': None,
#    'id': 799343,
#    'province': 'BC',
#    'source': 'https://news.gov.bc.ca/releases/2021HLTH0028-000199',
#    'travel_history': 'Pending'},
#   {'age': 'Pending',
#    'city': 'Pending',
# ...

# %% [markdown]
# ##**GET Request for daily COVID19 summaries for all Canadian provinces**

# %%
jsonresponse3 = requests.get('https://api.covid19tracker.ca/reports')
jsonresponse3.status_code
# Out:
# 200

# %% [markdown]
# ##**View of daily COVID19 summaries for all Canadian provinces**

# %%
jsonresponse3.json()
# Out:
# {'data': [{'change_cases': 1,
#    'change_criticals': 0,
#    'change_fatalities': 0,
#    'change_hospitalizations': 0,
#    'change_recoveries': 0,
#    'change_tests': 2,
#    'change_vaccinated': 0,
#    'change_vaccinations': 0,
#    'change_vaccines_distributed': 0,
#    'date': '2020-01-25',
#    'total_cases': 1,
#    'total_criticals': 0,
#    'total_fatalities': 0,
#    'total_hospitalizations': 0,
#    'total_recoveries': 0,
#    'total_tests': 2,
#    'total_vaccinated': 0,
#    'total_vaccinations': 0,
#    'total_vaccines_distributed': 0},
#   {'change_cases': 1,
#    'change_criticals': 0,
#    'change_fatalities': 0,
#    'change_hospitalizations': 0,
#    'change_recoveries': 0,
#    'change_tests': 4,
#    'change_vaccinated': 0,
#    'change_vaccinations': 0,
#    'change_vaccines_distributed': 0,
#    'date': '2020-01-26',
#    'total_cases': 2,
#    'total_criticals': 0,
#    'total_fatalities': 0,
#    'total_hospitalizations': 0,
#    'total_recoveries': 0,
# ...

# %% [markdown]
# ##Please reference the README.md file for additional information on the COVID19 tracking system in Canada and API documentation used for this assignment. Thank you!
